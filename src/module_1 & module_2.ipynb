# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import os
import csv
import glob
import numpy as np

# %%
BASE_PATH = "/content/drive/MyDrive/PCB_DATASET"

TEMPLATE_DIR = f"{BASE_PATH}/PCB_USED"
IMAGE_DIR    = f"{BASE_PATH}/images"

OUT_ALIGN = f"{BASE_PATH}/outputs/aligned"
OUT_DIFF  = f"{BASE_PATH}/outputs/diff"
OUT_MASK  = f"{BASE_PATH}/outputs/mask"
ROI_ROOT  = f"{BASE_PATH}/data/rois"
CSV_PATH  = f"{ROI_ROOT}/annotations.csv"

for d in [OUT_ALIGN, OUT_DIFF, OUT_MASK, ROI_ROOT]:
    os.makedirs(d, exist_ok=True)

# %% [markdown]
# # 1. ECC ALIGNMENT

# %%
def align_images(template, test):
    temp_gray = cv2.cvtColor(template, cv2.COLOR_BGR2GRAY)
    test_gray = cv2.cvtColor(test, cv2.COLOR_BGR2GRAY)

    warp_mode = cv2.MOTION_EUCLIDEAN
    warp_matrix = np.eye(2, 3, dtype=np.float32)

    criteria = (cv2.TERM_CRITERIA_EPS | cv2.TERM_CRITERIA_COUNT, 200, 1e-6)

    try:
        cc, warp_matrix = cv2.findTransformECC(temp_gray, test_gray, warp_matrix, warp_mode, criteria)
        aligned = cv2.warpAffine(test, warp_matrix, (template.shape[1], template.shape[0]),
                                 flags=cv2.INTER_LINEAR + cv2.WARP_INVERSE_MAP)
        return aligned
    except cv2.error as e:
        print("[ECC FAILED → Returning Test Image]", e)
        return test

# %% [markdown]
# # 2. PREPROCESS (Histogram Equalization Instead of Normalize)

# %%
def preprocess(img):
    g = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    g = cv2.GaussianBlur(g, (5,5), 0)
    g = cv2.equalizeHist(g)
    return g

# %% [markdown]
# # 3. MORPHOLOGY CLEANER

# %%
def denoise_mask(mask, defect):
    mask = cv2.medianBlur(mask, 3)

    kernel_open = np.ones((5,5), np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel_open, iterations=2)

    kernel_close = np.ones((5,5), np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel_close, iterations=1)

    return mask

# %% [markdown]
# # 4. CONNECTED COMPONENT FILTER

# %%
def cc_filter(mask, min_area=120):
    num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(mask, connectivity=8)
    cleaned = np.zeros_like(mask)

    for i in range(1, num_labels):
        area = stats[i, cv2.CC_STAT_AREA]
        if area >= min_area:
            cleaned[labels == i] = 255

    return cleaned

# %% [markdown]
# # MODULE-1 PIPELINE

# %%
def module1():
    defect_folders = os.listdir(IMAGE_DIR)

    for defect in defect_folders:
        folder_path = f"{IMAGE_DIR}/{defect}"
        if not os.path.isdir(folder_path): continue

        print(f"\n[MODULE-1] Processing defect type: {defect}")

        for fname in os.listdir(folder_path):
            if not fname.lower().endswith((".jpg",".png",".jpeg")): continue

            cid = fname.split("_")[0]
            template_candidates = glob.glob(f"{TEMPLATE_DIR}/{cid}.*")
            if not template_candidates:
                print("[NO TEMPLATE]:", fname)
                continue

            template = cv2.imread(template_candidates[0])
            test = cv2.imread(f"{folder_path}/{fname}")

            # 1) Align
            aligned = align_images(template, test)
            cv2.imwrite(f"{OUT_ALIGN}/{fname}", aligned)

            # 2) Preprocess
            temp_p = preprocess(template)
            test_p = preprocess(aligned)

            # 3) Subtract
            diff = cv2.absdiff(temp_p, test_p)
            cv2.imwrite(f"{OUT_DIFF}/{fname}", diff)

            # 4) Threshold
            _, otsu = cv2.threshold(diff, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

            # 5) Morphology
            den = denoise_mask(otsu, defect)

            # 6) Component Filtering
            clean = cc_filter(den, min_area=120)

            cv2.imwrite(f"{OUT_MASK}/{fname}", clean)

            print(f"[OK] {fname} → MASK SAVED")

    print("\n✔ MODULE-1 COMPLETED ✔")


# Run Module-1
module1()
# Out:
# [MODULE-1] Processing defect type: Spur
# [OK] 12_spur_08.jpg → MASK SAVED
# [OK] 11_spur_10.jpg → MASK SAVED
# [OK] 12_spur_03.jpg → MASK SAVED
# [OK] 12_spur_01.jpg → MASK SAVED
# [OK] 11_spur_09.jpg → MASK SAVED
# [OK] 12_spur_02.jpg → MASK SAVED
# [OK] 11_spur_04.jpg → MASK SAVED
# [OK] 12_spur_04.jpg → MASK SAVED
# [OK] 12_spur_10.jpg → MASK SAVED
# [OK] 12_spur_07.jpg → MASK SAVED
# [OK] 12_spur_05.jpg → MASK SAVED
# [OK] 11_spur_07.jpg → MASK SAVED
# [OK] 11_spur_06.jpg → MASK SAVED
# [OK] 11_spur_05.jpg → MASK SAVED
# [OK] 12_spur_09.jpg → MASK SAVED
# [OK] 11_spur_08.jpg → MASK SAVED
# [OK] 12_spur_06.jpg → MASK SAVED
# [OK] 07_spur_03.jpg → MASK SAVED
# [OK] 05_spur_02.jpg → MASK SAVED
# [OK] 08_spur_06.jpg → MASK SAVED
# [OK] 07_spur_02.jpg → MASK SAVED
# [OK] 06_spur_07.jpg → MASK SAVED
# [OK] 10_spur_01.jpg → MASK SAVED
# [OK] 10_spur_03.jpg → MASK SAVED
# [OK] 06_spur_09.jpg → MASK SAVED
# [OK] 05_spur_09.jpg → MASK SAVED
# [OK] 08_spur_07.jpg → MASK SAVED
# [OK] 06_spur_04.jpg → MASK SAVED
# [OK] 08_spur_05.jpg → MASK SAVED
# [OK] 07_spur_09.jpg → MASK SAVED
# [OK] 07_spur_05.jpg → MASK SAVED
# [OK] 09_spur_10.jpg → MASK SAVED
# [OK] 11_spur_02.jpg → MASK SAVED
# [OK] 09_spur_06.jpg → MASK SAVED
# [OK] 06_spur_02.jpg → MASK SAVED
# [OK] 07_spur_01.jpg → MASK SAVED
# [OK] 09_spur_03.jpg → MASK SAVED
# [OK] 09_spur_09.jpg → MASK SAVED
# [OK] 05_spur_01.jpg → MASK SAVED
# [OK] 06_spur_08.jpg → MASK SAVED
# [OK] 08_spur_10.jpg → MASK SAVED
# [OK] 08_spur_08.jpg → MASK SAVED
# [OK] 11_spur_01.jpg → MASK SAVED
# [OK] 04_spur_20.jpg → MASK SAVED
# [OK] 05_spur_08.jpg → MASK SAVED
# [OK] 05_spur_04.jpg → MASK SAVED
# [OK] 05_spur_03.jpg → MASK SAVED
# [OK] 08_spur_03.jpg → MASK SAVED
# [OK] 05_spur_10.jpg → MASK SAVED
# [OK] 07_spur_10.jpg → MASK SAVED
# [OK] 06_spur_06.jpg → MASK SAVED
# [OK] 08_spur_02.jpg → MASK SAVED
# [OK] 07_spur_08.jpg → MASK SAVED
# [OK] 04_spur_19.jpg → MASK SAVED
# [OK] 09_spur_02.jpg → MASK SAVED
# [OK] 07_spur_07.jpg → MASK SAVED
# [OK] 08_spur_01.jpg → MASK SAVED
# [OK] 06_spur_03.jpg → MASK SAVED
# [OK] 09_spur_05.jpg → MASK SAVED
# [OK] 07_spur_04.jpg → MASK SAVED
# [OK] 07_spur_06.jpg → MASK SAVED
# [OK] 10_spur_05.jpg → MASK SAVED
# [OK] 05_spur_07.jpg → MASK SAVED
# [OK] 09_spur_08.jpg → MASK SAVED
# [OK] 05_spur_05.jpg → MASK SAVED
# [OK] 10_spur_02.jpg → MASK SAVED
# [OK] 09_spur_07.jpg → MASK SAVED
# [OK] 08_spur_09.jpg → MASK SAVED
# [OK] 06_spur_10.jpg → MASK SAVED
# [OK] 09_spur_04.jpg → MASK SAVED
# [OK] 05_spur_06.jpg → MASK SAVED
# [OK] 10_spur_04.jpg → MASK SAVED
# [OK] 06_spur_05.jpg → MASK SAVED
# [OK] 06_spur_01.jpg → MASK SAVED
# [OK] 09_spur_01.jpg → MASK SAVED
# [OK] 08_spur_04.jpg → MASK SAVED
# [OK] 11_spur_03.jpg → MASK SAVED
# [OK] 01_spur_10.jpg → MASK SAVED
# [OK] 01_spur_14.jpg → MASK SAVED
# [OK] 01_spur_08.jpg → MASK SAVED
# [OK] 04_spur_16.jpg → MASK SAVED
# [OK] 04_spur_07.jpg → MASK SAVED
# [OK] 04_spur_13.jpg → MASK SAVED
# [OK] 01_spur_11.jpg → MASK SAVED
# [OK] 04_spur_10.jpg → MASK SAVED
# [OK] 04_spur_15.jpg → MASK SAVED
# [OK] 01_spur_03.jpg → MASK SAVED
# [OK] 04_spur_14.jpg → MASK SAVED
# [OK] 01_spur_17.jpg → MASK SAVED
# [OK] 04_spur_02.jpg → MASK SAVED
# [OK] 04_spur_03.jpg → MASK SAVED
# [OK] 01_spur_01.jpg → MASK SAVED
# [OK] 04_spur_01.jpg → MASK SAVED
# [OK] 04_spur_04.jpg → MASK SAVED
# [OK] 04_spur_09.jpg → MASK SAVED
# [OK] 01_spur_16.jpg → MASK SAVED
# [OK] 01_spur_20.jpg → MASK SAVED
# [OK] 01_spur_09.jpg → MASK SAVED
# [OK] 04_spur_06.jpg → MASK SAVED
# [OK] 01_spur_19.jpg → MASK SAVED
# [OK] 01_spur_06.jpg → MASK SAVED
# [OK] 01_spur_12.jpg → MASK SAVED
# [OK] 01_spur_18.jpg → MASK SAVED
# [OK] 04_spur_05.jpg → MASK SAVED
# [OK] 01_spur_04.jpg → MASK SAVED
# [OK] 04_spur_18.jpg → MASK SAVED
# [OK] 01_spur_13.jpg → MASK SAVED
# [OK] 04_spur_17.jpg → MASK SAVED
# [OK] 01_spur_05.jpg → MASK SAVED
# [OK] 04_spur_08.jpg → MASK SAVED
# [OK] 04_spur_11.jpg → MASK SAVED
# [OK] 04_spur_12.jpg → MASK SAVED
# [OK] 01_spur_07.jpg → MASK SAVED
# [OK] 01_spur_15.jpg → MASK SAVED
# [OK] 01_spur_02.jpg → MASK SAVED
#
# [MODULE-1] Processing defect type: Spurious_copper
# [OK] 08_spurious_copper_10.jpg → MASK SAVED
# [OK] 09_spurious_copper_07.jpg → MASK SAVED
# [OK] 12_spurious_copper_06.jpg → MASK SAVED
# [OK] 09_spurious_copper_05.jpg → MASK SAVED
# [OK] 09_spurious_copper_06.jpg → MASK SAVED
# [OK] 12_spurious_copper_10.jpg → MASK SAVED
# [OK] 08_spurious_copper_08.jpg → MASK SAVED
# [OK] 12_spurious_copper_03.jpg → MASK SAVED
# [OK] 10_spurious_copper_04.jpg → MASK SAVED
# [OK] 09_spurious_copper_02.jpg → MASK SAVED
# [OK] 09_spurious_copper_09.jpg → MASK SAVED
# [OK] 12_spurious_copper_01.jpg → MASK SAVED
# [OK] 10_spurious_copper_05.jpg → MASK SAVED
# [OK] 10_spurious_copper_06.jpg → MASK SAVED
# [OK] 11_spurious_copper_08.jpg → MASK SAVED
# [OK] 12_spurious_copper_09.jpg → MASK SAVED
# [OK] 11_spurious_copper_09.jpg → MASK SAVED
# [OK] 12_spurious_copper_08.jpg → MASK SAVED
# [OK] 11_spurious_copper_07.jpg → MASK SAVED
# [OK] 11_spurious_copper_01.jpg → MASK SAVED
# [OK] 09_spurious_copper_10.jpg → MASK SAVED
# [OK] 10_spurious_copper_03.jpg → MASK SAVED
# [OK] 08_spurious_copper_09.jpg → MASK SAVED
# [OK] 11_spurious_copper_03.jpg → MASK SAVED
# [OK] 09_spurious_copper_04.jpg → MASK SAVED
# [OK] 09_spurious_copper_01.jpg → MASK SAVED
# [OK] 11_spurious_copper_05.jpg → MASK SAVED
# [OK] 10_spurious_copper_02.jpg → MASK SAVED
# [OK] 08_spurious_copper_07.jpg → MASK SAVED
# [OK] 10_spurious_copper_01.jpg → MASK SAVED
# [OK] 09_spurious_copper_08.jpg → MASK SAVED
# [OK] 11_spurious_copper_02.jpg → MASK SAVED
# [OK] 11_spurious_copper_06.jpg → MASK SAVED
# [OK] 11_spurious_copper_10.jpg → MASK SAVED
# [OK] 11_spurious_copper_04.jpg → MASK SAVED
# [OK] 12_spurious_copper_05.jpg → MASK SAVED
# [OK] 12_spurious_copper_07.jpg → MASK SAVED
# [OK] 12_spurious_copper_04.jpg → MASK SAVED
# [OK] 09_spurious_copper_03.jpg → MASK SAVED
# [OK] 12_spurious_copper_02.jpg → MASK SAVED
# [OK] 06_spurious_copper_05.jpg → MASK SAVED
# [OK] 06_spurious_copper_09.jpg → MASK SAVED
# [OK] 08_spurious_copper_04.jpg → MASK SAVED
# [OK] 07_spurious_copper_10.jpg → MASK SAVED
# [OK] 06_spurious_copper_02.jpg → MASK SAVED
# [OK] 07_spurious_copper_02.jpg → MASK SAVED
# [OK] 08_spurious_copper_05.jpg → MASK SAVED
# [OK] 08_spurious_copper_03.jpg → MASK SAVED
# [OK] 05_spurious_copper_04.jpg → MASK SAVED
# [OK] 06_spurious_copper_04.jpg → MASK SAVED
# [OK] 05_spurious_copper_06.jpg → MASK SAVED
# [OK] 08_spurious_copper_01.jpg → MASK SAVED
# [OK] 04_spurious_copper_14.jpg → MASK SAVED
# [OK] 06_spurious_copper_01.jpg → MASK SAVED
# [OK] 07_spurious_copper_05.jpg → MASK SAVED
# [OK] 05_spurious_copper_08.jpg → MASK SAVED
# [OK] 07_spurious_copper_03.jpg → MASK SAVED
# [OK] 07_spurious_copper_09.jpg → MASK SAVED
# [OK] 07_spurious_copper_07.jpg → MASK SAVED
# [OK] 06_spurious_copper_07.jpg → MASK SAVED
# [OK] 06_spurious_copper_08.jpg → MASK SAVED
# [OK] 05_spurious_copper_02.jpg → MASK SAVED
# [OK] 05_spurious_copper_01.jpg → MASK SAVED
# [OK] 05_spurious_copper_03.jpg → MASK SAVED
# [OK] 04_spurious_copper_20.jpg → MASK SAVED
# [OK] 07_spurious_copper_06.jpg → MASK SAVED
# [OK] 05_spurious_copper_07.jpg → MASK SAVED
# [OK] 06_spurious_copper_10.jpg → MASK SAVED
# [OK] 04_spurious_copper_16.jpg → MASK SAVED
# [OK] 04_spurious_copper_18.jpg → MASK SAVED
# [OK] 05_spurious_copper_09.jpg → MASK SAVED
# [OK] 04_spurious_copper_17.jpg → MASK SAVED
# [OK] 04_spurious_copper_19.jpg → MASK SAVED
# [OK] 07_spurious_copper_01.jpg → MASK SAVED
# [OK] 04_spurious_copper_15.jpg → MASK SAVED
# [OK] 07_spurious_copper_04.jpg → MASK SAVED
# [OK] 06_spurious_copper_03.jpg → MASK SAVED
# [OK] 04_spurious_copper_13.jpg → MASK SAVED
# [OK] 06_spurious_copper_06.jpg → MASK SAVED
# [OK] 08_spurious_copper_02.jpg → MASK SAVED
# [OK] 05_spurious_copper_05.jpg → MASK SAVED
# [OK] 07_spurious_copper_08.jpg → MASK SAVED
# [OK] 08_spurious_copper_06.jpg → MASK SAVED
# [OK] 05_spurious_copper_10.jpg → MASK SAVED
# [OK] 04_spurious_copper_09.jpg → MASK SAVED
# [OK] 01_spurious_copper_08.jpg → MASK SAVED
# [OK] 04_spurious_copper_07.jpg → MASK SAVED
# [OK] 01_spurious_copper_01.jpg → MASK SAVED
# [OK] 01_spurious_copper_11.jpg → MASK SAVED
# [OK] 01_spurious_copper_12.jpg → MASK SAVED
# [OK] 01_spurious_copper_19.jpg → MASK SAVED
# [OK] 04_spurious_copper_04.jpg → MASK SAVED
# [OK] 01_spurious_copper_20.jpg → MASK SAVED
# [OK] 01_spurious_copper_16.jpg → MASK SAVED
# [OK] 04_spurious_copper_02.jpg → MASK SAVED
# [OK] 01_spurious_copper_15.jpg → MASK SAVED
# [OK] 01_spurious_copper_06.jpg → MASK SAVED
# [OK] 01_spurious_copper_05.jpg → MASK SAVED
# [OK] 01_spurious_copper_07.jpg → MASK SAVED
# [OK] 01_spurious_copper_02.jpg → MASK SAVED
# [OK] 04_spurious_copper_11.jpg → MASK SAVED
# [OK] 04_spurious_copper_10.jpg → MASK SAVED
# [OK] 01_spurious_copper_10.jpg → MASK SAVED
# [OK] 04_spurious_copper_03.jpg → MASK SAVED
# [OK] 01_spurious_copper_14.jpg → MASK SAVED
# [OK] 04_spurious_copper_05.jpg → MASK SAVED
# [OK] 01_spurious_copper_18.jpg → MASK SAVED
# [OK] 04_spurious_copper_08.jpg → MASK SAVED
# [OK] 01_spurious_copper_04.jpg → MASK SAVED
# [OK] 04_spurious_copper_01.jpg → MASK SAVED
# [OK] 01_spurious_copper_03.jpg → MASK SAVED
# [OK] 01_spurious_copper_13.jpg → MASK SAVED
# [OK] 04_spurious_copper_12.jpg → MASK SAVED
# [OK] 01_spurious_copper_09.jpg → MASK SAVED
# [OK] 01_spurious_copper_17.jpg → MASK SAVED
# [OK] 04_spurious_copper_06.jpg → MASK SAVED
#
# [MODULE-1] Processing defect type: Short
# [OK] 08_short_09.jpg → MASK SAVED
# [OK] 11_short_04.jpg → MASK SAVED
# [OK] 12_short_01.jpg → MASK SAVED
# [OK] 11_short_03.jpg → MASK SAVED
# [OK] 09_short_07.jpg → MASK SAVED
# [OK] 09_short_03.jpg → MASK SAVED
# [OK] 09_short_01.jpg → MASK SAVED
# [OK] 12_short_10.jpg → MASK SAVED
# [OK] 12_short_02.jpg → MASK SAVED
# [OK] 09_short_02.jpg → MASK SAVED
# [OK] 10_short_01.jpg → MASK SAVED
# [OK] 11_short_02.jpg → MASK SAVED
# [OK] 09_short_10.jpg → MASK SAVED
# [OK] 10_short_04.jpg → MASK SAVED
# [OK] 11_short_09.jpg → MASK SAVED
# [OK] 11_short_10.jpg → MASK SAVED
# [OK] 11_short_01.jpg → MASK SAVED
# [OK] 11_short_05.jpg → MASK SAVED
# [OK] 11_short_08.jpg → MASK SAVED
# [OK] 09_short_04.jpg → MASK SAVED
# [OK] 09_short_09.jpg → MASK SAVED
# [OK] 12_short_04.jpg → MASK SAVED
# [OK] 10_short_02.jpg → MASK SAVED
# [OK] 10_short_05.jpg → MASK SAVED
# [OK] 12_short_07.jpg → MASK SAVED
# [OK] 11_short_06.jpg → MASK SAVED
# [OK] 09_short_08.jpg → MASK SAVED
# [OK] 12_short_03.jpg → MASK SAVED
# [OK] 11_short_07.jpg → MASK SAVED
# [OK] 09_short_06.jpg → MASK SAVED
# [OK] 09_short_05.jpg → MASK SAVED
# [OK] 12_short_06.jpg → MASK SAVED
# [OK] 12_short_09.jpg → MASK SAVED
# [OK] 12_short_08.jpg → MASK SAVED
# [OK] 08_short_10.jpg → MASK SAVED
# [OK] 12_short_05.jpg → MASK SAVED
# [OK] 10_short_03.jpg → MASK SAVED
# [OK] 04_short_20.jpg → MASK SAVED
# [OK] 04_short_13.jpg → MASK SAVED
# [OK] 06_short_11.jpg → MASK SAVED
# [OK] 07_short_01.jpg → MASK SAVED
# [OK] 05_short_07.jpg → MASK SAVED
# [OK] 06_short_06.jpg → MASK SAVED
# [OK] 04_short_15.jpg → MASK SAVED
# [OK] 07_short_03.jpg → MASK SAVED
# [OK] 08_short_03.jpg → MASK SAVED
# [OK] 05_short_03.jpg → MASK SAVED
# [OK] 08_short_07.jpg → MASK SAVED
# [OK] 06_short_09.jpg → MASK SAVED
# [OK] 04_short_10.jpg → MASK SAVED
# [OK] 06_short_04.jpg → MASK SAVED
# [OK] 06_short_03.jpg → MASK SAVED
# [OK] 04_short_12.jpg → MASK SAVED
# [OK] 05_short_04.jpg → MASK SAVED
# [OK] 07_short_06.jpg → MASK SAVED
# [OK] 07_short_08.jpg → MASK SAVED
# [OK] 04_short_14.jpg → MASK SAVED
# [OK] 06_short_10.jpg → MASK SAVED
# [OK] 08_short_08.jpg → MASK SAVED
# [OK] 08_short_04.jpg → MASK SAVED
# [OK] 05_short_05.jpg → MASK SAVED
# [OK] 06_short_05.jpg → MASK SAVED
# [OK] 04_short_17.jpg → MASK SAVED
# [OK] 08_short_01.jpg → MASK SAVED
# [OK] 05_short_09.jpg → MASK SAVED
# [OK] 08_short_06.jpg → MASK SAVED
# [OK] 07_short_02.jpg → MASK SAVED
# [OK] 05_short_08.jpg → MASK SAVED
# [OK] 04_short_03.jpg → MASK SAVED
# [OK] 04_short_19.jpg → MASK SAVED
# [OK] 07_short_04.jpg → MASK SAVED
# [OK] 07_short_05.jpg → MASK SAVED
# [OK] 08_short_02.jpg → MASK SAVED
# [OK] 07_short_10.jpg → MASK SAVED
# [OK] 08_short_05.jpg → MASK SAVED
# [OK] 04_short_11.jpg → MASK SAVED
# [OK] 05_short_01.jpg → MASK SAVED
# [OK] 06_short_07.jpg → MASK SAVED
# [OK] 04_short_09.jpg → MASK SAVED
# [OK] 06_short_08.jpg → MASK SAVED
# [OK] 05_short_02.jpg → MASK SAVED
# [OK] 05_short_10.jpg → MASK SAVED
# [OK] 04_short_18.jpg → MASK SAVED
# [OK] 07_short_07.jpg → MASK SAVED
# [OK] 07_short_09.jpg → MASK SAVED
# [OK] 04_short_16.jpg → MASK SAVED
# [OK] 05_short_06.jpg → MASK SAVED
# [OK] 01_short_14.jpg → MASK SAVED
# [OK] 01_short_20.jpg → MASK SAVED
# [OK] 01_short_04.jpg → MASK SAVED
# [OK] 01_short_01.jpg → MASK SAVED
# [OK] 01_short_07.jpg → MASK SAVED
# [OK] 01_short_13.jpg → MASK SAVED
# [OK] 01_short_19.jpg → MASK SAVED
# [OK] 04_short_07.jpg → MASK SAVED
# [OK] 06_short_01.jpg → MASK SAVED
# [OK] 01_short_02.jpg → MASK SAVED
# [OK] 04_short_01.jpg → MASK SAVED
# [OK] 01_short_15.jpg → MASK SAVED
# [OK] 01_short_10.jpg → MASK SAVED
# [OK] 01_short_18.jpg → MASK SAVED
# [OK] 01_short_16.jpg → MASK SAVED
# [OK] 04_short_04.jpg → MASK SAVED
# [OK] 06_short_02.jpg → MASK SAVED
# [OK] 04_short_05.jpg → MASK SAVED
# [OK] 01_short_05.jpg → MASK SAVED
# [OK] 01_short_03.jpg → MASK SAVED
# [OK] 01_short_17.jpg → MASK SAVED
# [OK] 04_short_08.jpg → MASK SAVED
# [OK] 01_short_09.jpg → MASK SAVED
# [OK] 04_short_06.jpg → MASK SAVED
# [OK] 01_short_06.jpg → MASK SAVED
# [OK] 04_short_02.jpg → MASK SAVED
# [OK] 01_short_08.jpg → MASK SAVED
# [OK] 01_short_11.jpg → MASK SAVED
# [OK] 01_short_12.jpg → MASK SAVED
#
# [MODULE-1] Processing defect type: Open_circuit
# [OK] 12_open_circuit_06.jpg → MASK SAVED
# [OK] 12_open_circuit_04.jpg → MASK SAVED
# [OK] 11_open_circuit_08.jpg → MASK SAVED
# [OK] 12_open_circuit_10.jpg → MASK SAVED
# [OK] 11_open_circuit_03.jpg → MASK SAVED
# [OK] 11_open_circuit_04.jpg → MASK SAVED
# [OK] 09_open_circuit_08.jpg → MASK SAVED
# [OK] 12_open_circuit_09.jpg → MASK SAVED
# [OK] 11_open_circuit_06.jpg → MASK SAVED
# [OK] 11_open_circuit_01.jpg → MASK SAVED
# [OK] 10_open_circuit_01.jpg → MASK SAVED
# [OK] 12_open_circuit_01.jpg → MASK SAVED
# [OK] 09_open_circuit_09.jpg → MASK SAVED
# [OK] 09_open_circuit_10.jpg → MASK SAVED
# [OK] 11_open_circuit_02.jpg → MASK SAVED
# [OK] 11_open_circuit_10.jpg → MASK SAVED
# [OK] 12_open_circuit_05.jpg → MASK SAVED
# [OK] 11_open_circuit_07.jpg → MASK SAVED
# [OK] 12_open_circuit_08.jpg → MASK SAVED
# [OK] 01_open_circuit_01.jpg → MASK SAVED
# [OK] 11_open_circuit_09.jpg → MASK SAVED
# [OK] 12_open_circuit_02.jpg → MASK SAVED
# [OK] 10_open_circuit_03.jpg → MASK SAVED
# [OK] 12_open_circuit_07.jpg → MASK SAVED
# [OK] 10_open_circuit_04.jpg → MASK SAVED
# [OK] 10_open_circuit_06.jpg → MASK SAVED
# [OK] 10_open_circuit_05.jpg → MASK SAVED
# [OK] 12_open_circuit_03.jpg → MASK SAVED
# [OK] 10_open_circuit_02.jpg → MASK SAVED
# [OK] 11_open_circuit_05.jpg → MASK SAVED
# [OK] 06_open_circuit_10.jpg → MASK SAVED
# [OK] 09_open_circuit_02.jpg → MASK SAVED
# [OK] 08_open_circuit_05.jpg → MASK SAVED
# [OK] 08_open_circuit_02.jpg → MASK SAVED
# [OK] 08_open_circuit_03.jpg → MASK SAVED
# [OK] 08_open_circuit_10.jpg → MASK SAVED
# [OK] 09_open_circuit_01.jpg → MASK SAVED
# [OK] 07_open_circuit_10.jpg → MASK SAVED
# [OK] 07_open_circuit_07.jpg → MASK SAVED
# [OK] 07_open_circuit_02.jpg → MASK SAVED
# [OK] 07_open_circuit_04.jpg → MASK SAVED
# [OK] 08_open_circuit_09.jpg → MASK SAVED
# [OK] 06_open_circuit_08.jpg → MASK SAVED
# [OK] 07_open_circuit_05.jpg → MASK SAVED
# [OK] 06_open_circuit_09.jpg → MASK SAVED
# [OK] 09_open_circuit_06.jpg → MASK SAVED
# [OK] 08_open_circuit_07.jpg → MASK SAVED
# [OK] 06_open_circuit_07.jpg → MASK SAVED
# [OK] 09_open_circuit_05.jpg → MASK SAVED
# [OK] 08_open_circuit_01.jpg → MASK SAVED
# [OK] 07_open_circuit_09.jpg → MASK SAVED
# [OK] 08_open_circuit_04.jpg → MASK SAVED
# [OK] 07_open_circuit_01.jpg → MASK SAVED
# [OK] 09_open_circuit_07.jpg → MASK SAVED
# [OK] 08_open_circuit_06.jpg → MASK SAVED
# [OK] 06_open_circuit_06.jpg → MASK SAVED
# [OK] 07_open_circuit_08.jpg → MASK SAVED
# [OK] 07_open_circuit_06.jpg → MASK SAVED
# [OK] 07_open_circuit_03.jpg → MASK SAVED
# [OK] 08_open_circuit_08.jpg → MASK SAVED
# [OK] 09_open_circuit_04.jpg → MASK SAVED
# [OK] 09_open_circuit_03.jpg → MASK SAVED
# [OK] 04_open_circuit_01.jpg → MASK SAVED
# [OK] 06_open_circuit_01.jpg → MASK SAVED
# [OK] 01_open_circuit_20.jpg → MASK SAVED
# [OK] 04_open_circuit_02.jpg → MASK SAVED
# [OK] 06_open_circuit_05.jpg → MASK SAVED
# [OK] 05_open_circuit_03.jpg → MASK SAVED
# [OK] 04_open_circuit_05.jpg → MASK SAVED
# [OK] 04_open_circuit_03.jpg → MASK SAVED
# [OK] 04_open_circuit_10.jpg → MASK SAVED
# [OK] 05_open_circuit_02.jpg → MASK SAVED
# [OK] 05_open_circuit_08.jpg → MASK SAVED
# [OK] 01_open_circuit_18.jpg → MASK SAVED
# [OK] 04_open_circuit_17.jpg → MASK SAVED
# [OK] 06_open_circuit_03.jpg → MASK SAVED
# [OK] 05_open_circuit_06.jpg → MASK SAVED
# [OK] 05_open_circuit_05.jpg → MASK SAVED
# [OK] 05_open_circuit_10.jpg → MASK SAVED
# [OK] 05_open_circuit_09.jpg → MASK SAVED
# [OK] 01_open_circuit_19.jpg → MASK SAVED
# [OK] 04_open_circuit_19.jpg → MASK SAVED
# [OK] 06_open_circuit_04.jpg → MASK SAVED
# [OK] 06_open_circuit_02.jpg → MASK SAVED
# [OK] 04_open_circuit_04.jpg → MASK SAVED
# [OK] 04_open_circuit_20.jpg → MASK SAVED
# [OK] 01_open_circuit_17.jpg → MASK SAVED
# [OK] 04_open_circuit_18.jpg → MASK SAVED
# [OK] 05_open_circuit_07.jpg → MASK SAVED
# [OK] 04_open_circuit_11.jpg → MASK SAVED
# [OK] 04_open_circuit_13.jpg → MASK SAVED
# [OK] 04_open_circuit_09.jpg → MASK SAVED
# [OK] 01_open_circuit_16.jpg → MASK SAVED
# [OK] 01_open_circuit_15.jpg → MASK SAVED
# [OK] 04_open_circuit_15.jpg → MASK SAVED
# [OK] 05_open_circuit_01.jpg → MASK SAVED
# [OK] 04_open_circuit_12.jpg → MASK SAVED
# [OK] 01_open_circuit_14.jpg → MASK SAVED
# [OK] 04_open_circuit_07.jpg → MASK SAVED
# [OK] 04_open_circuit_06.jpg → MASK SAVED
# [OK] 04_open_circuit_08.jpg → MASK SAVED
# [OK] 05_open_circuit_04.jpg → MASK SAVED
# [OK] 04_open_circuit_16.jpg → MASK SAVED
# [OK] 04_open_circuit_14.jpg → MASK SAVED
# [OK] 01_open_circuit_13.jpg → MASK SAVED
# [OK] 01_open_circuit_12.jpg → MASK SAVED
# [OK] 01_open_circuit_05.jpg → MASK SAVED
# [OK] 01_open_circuit_07.jpg → MASK SAVED
# [OK] 01_open_circuit_10.jpg → MASK SAVED
# [OK] 01_open_circuit_02.jpg → MASK SAVED
# [OK] 01_open_circuit_11.jpg → MASK SAVED
# [OK] 01_open_circuit_06.jpg → MASK SAVED
# [OK] 01_open_circuit_04.jpg → MASK SAVED
# [OK] 01_open_circuit_09.jpg → MASK SAVED
# [OK] 01_open_circuit_03.jpg → MASK SAVED
# [OK] 01_open_circuit_08.jpg → MASK SAVED
#
# [MODULE-1] Processing defect type: Missing_hole
# [OK] 12_missing_hole_03.jpg → MASK SAVED
# [OK] 12_missing_hole_10.jpg → MASK SAVED
# [OK] 12_missing_hole_04.jpg → MASK SAVED
# [OK] 12_missing_hole_07.jpg → MASK SAVED
# [OK] 12_missing_hole_08.jpg → MASK SAVED
# [OK] 12_missing_hole_05.jpg → MASK SAVED
# [OK] 12_missing_hole_06.jpg → MASK SAVED
# [OK] 12_missing_hole_09.jpg → MASK SAVED
# [OK] 12_missing_hole_02.jpg → MASK SAVED
# [OK] 07_missing_hole_08.jpg → MASK SAVED
# [OK] 07_missing_hole_10.jpg → MASK SAVED
# [OK] 09_missing_hole_07.jpg → MASK SAVED
# [OK] 10_missing_hole_04.jpg → MASK SAVED
# [OK] 11_missing_hole_04.jpg → MASK SAVED
# [OK] 07_missing_hole_09.jpg → MASK SAVED
# [OK] 09_missing_hole_10.jpg → MASK SAVED
# [OK] 08_missing_hole_06.jpg → MASK SAVED
# [OK] 07_missing_hole_03.jpg → MASK SAVED
# [OK] 07_missing_hole_06.jpg → MASK SAVED
# [OK] 10_missing_hole_05.jpg → MASK SAVED
# [OK] 09_missing_hole_06.jpg → MASK SAVED
# [OK] 09_missing_hole_01.jpg → MASK SAVED
# [OK] 08_missing_hole_07.jpg → MASK SAVED
# [OK] 06_missing_hole_09.jpg → MASK SAVED
# [OK] 11_missing_hole_07.jpg → MASK SAVED
# [OK] 08_missing_hole_10.jpg → MASK SAVED
# [OK] 11_missing_hole_06.jpg → MASK SAVED
# [OK] 09_missing_hole_04.jpg → MASK SAVED
# [OK] 11_missing_hole_01.jpg → MASK SAVED
# [OK] 11_missing_hole_02.jpg → MASK SAVED
# [OK] 08_missing_hole_01.jpg → MASK SAVED
# [OK] 09_missing_hole_03.jpg → MASK SAVED
# [OK] 12_missing_hole_01.jpg → MASK SAVED
# [OK] 11_missing_hole_08.jpg → MASK SAVED
# [OK] 09_missing_hole_08.jpg → MASK SAVED
# [OK] 10_missing_hole_03.jpg → MASK SAVED
# [OK] 08_missing_hole_03.jpg → MASK SAVED
# [OK] 07_missing_hole_05.jpg → MASK SAVED
# [OK] 06_missing_hole_10.jpg → MASK SAVED
# [OK] 08_missing_hole_09.jpg → MASK SAVED
# [OK] 11_missing_hole_09.jpg → MASK SAVED
# [OK] 08_missing_hole_04.jpg → MASK SAVED
# [OK] 08_missing_hole_08.jpg → MASK SAVED
# [OK] 11_missing_hole_05.jpg → MASK SAVED
# [OK] 11_missing_hole_03.jpg → MASK SAVED
# [OK] 09_missing_hole_02.jpg → MASK SAVED
# [OK] 07_missing_hole_02.jpg → MASK SAVED
# [OK] 09_missing_hole_05.jpg → MASK SAVED
# [OK] 10_missing_hole_01.jpg → MASK SAVED
# [OK] 08_missing_hole_02.jpg → MASK SAVED
# [OK] 07_missing_hole_04.jpg → MASK SAVED
# [OK] 10_missing_hole_02.jpg → MASK SAVED
# [OK] 07_missing_hole_07.jpg → MASK SAVED
# [OK] 08_missing_hole_05.jpg → MASK SAVED
# [OK] 11_missing_hole_10.jpg → MASK SAVED
# [OK] 07_missing_hole_01.jpg → MASK SAVED
# [OK] 09_missing_hole_09.jpg → MASK SAVED
# [OK] 06_missing_hole_08.jpg → MASK SAVED
# [OK] 05_missing_hole_05.jpg → MASK SAVED
# [OK] 04_missing_hole_13.jpg → MASK SAVED
# [OK] 04_missing_hole_18.jpg → MASK SAVED
# [OK] 04_missing_hole_15.jpg → MASK SAVED
# [OK] 04_missing_hole_03.jpg → MASK SAVED
# [OK] 04_missing_hole_05.jpg → MASK SAVED
# [OK] 04_missing_hole_12.jpg → MASK SAVED
# [OK] 05_missing_hole_03.jpg → MASK SAVED
# [OK] 04_missing_hole_17.jpg → MASK SAVED
# [OK] 06_missing_hole_01.jpg → MASK SAVED
# [OK] 04_missing_hole_10.jpg → MASK SAVED
# [OK] 04_missing_hole_11.jpg → MASK SAVED
# [OK] 05_missing_hole_06.jpg → MASK SAVED
# [OK] 05_missing_hole_10.jpg → MASK SAVED
# [OK] 04_missing_hole_04.jpg → MASK SAVED
# [OK] 05_missing_hole_08.jpg → MASK SAVED
# [OK] 06_missing_hole_06.jpg → MASK SAVED
# [OK] 04_missing_hole_07.jpg → MASK SAVED
# [OK] 06_missing_hole_02.jpg → MASK SAVED
# [OK] 04_missing_hole_08.jpg → MASK SAVED
# [OK] 04_missing_hole_14.jpg → MASK SAVED
# [OK] 05_missing_hole_07.jpg → MASK SAVED
# [OK] 04_missing_hole_20.jpg → MASK SAVED
# [OK] 05_missing_hole_04.jpg → MASK SAVED
# [OK] 05_missing_hole_02.jpg → MASK SAVED
# [OK] 04_missing_hole_09.jpg → MASK SAVED
# [OK] 05_missing_hole_09.jpg → MASK SAVED
# [OK] 04_missing_hole_06.jpg → MASK SAVED
# [OK] 06_missing_hole_07.jpg → MASK SAVED
# [OK] 04_missing_hole_02.jpg → MASK SAVED
# [OK] 06_missing_hole_03.jpg → MASK SAVED
# [OK] 06_missing_hole_05.jpg → MASK SAVED
# [OK] 04_missing_hole_19.jpg → MASK SAVED
# [OK] 06_missing_hole_04.jpg → MASK SAVED
# [OK] 05_missing_hole_01.jpg → MASK SAVED
# [OK] 04_missing_hole_16.jpg → MASK SAVED
# [OK] 01_missing_hole_12.jpg → MASK SAVED
# [OK] 01_missing_hole_02.jpg → MASK SAVED
# [OK] 01_missing_hole_18.jpg → MASK SAVED
# [OK] 01_missing_hole_10.jpg → MASK SAVED
# [OK] 01_missing_hole_05.jpg → MASK SAVED
# [OK] 04_missing_hole_01.jpg → MASK SAVED
# [OK] 01_missing_hole_01.jpg → MASK SAVED
# [OK] 01_missing_hole_07.jpg → MASK SAVED
# [OK] 01_missing_hole_16.jpg → MASK SAVED
# [OK] 01_missing_hole_14.jpg → MASK SAVED
# [OK] 01_missing_hole_11.jpg → MASK SAVED
# [OK] 01_missing_hole_04.jpg → MASK SAVED
# [OK] 01_missing_hole_13.jpg → MASK SAVED
# [OK] 01_missing_hole_20.jpg → MASK SAVED
# [OK] 01_missing_hole_15.jpg → MASK SAVED
# [OK] 01_missing_hole_09.jpg → MASK SAVED
# [OK] 01_missing_hole_08.jpg → MASK SAVED
# [OK] 01_missing_hole_17.jpg → MASK SAVED
# [OK] 01_missing_hole_03.jpg → MASK SAVED
# [OK] 01_missing_hole_19.jpg → MASK SAVED
# [OK] 01_missing_hole_06.jpg → MASK SAVED
#
# [MODULE-1] Processing defect type: Mouse_bite
# [OK] 11_mouse_bite_10.jpg → MASK SAVED
# [OK] 12_mouse_bite_03.jpg → MASK SAVED
# [OK] 12_mouse_bite_08.jpg → MASK SAVED
# [OK] 12_mouse_bite_06.jpg → MASK SAVED
# [OK] 12_mouse_bite_09.jpg → MASK SAVED
# [OK] 12_mouse_bite_04.jpg → MASK SAVED
# [OK] 12_mouse_bite_10.jpg → MASK SAVED
# [OK] 11_mouse_bite_09.jpg → MASK SAVED
# [OK] 12_mouse_bite_01.jpg → MASK SAVED
# [OK] 12_mouse_bite_07.jpg → MASK SAVED
# [OK] 12_mouse_bite_02.jpg → MASK SAVED
# [OK] 12_mouse_bite_05.jpg → MASK SAVED
# [OK] 06_mouse_bite_02.jpg → MASK SAVED
# [OK] 09_mouse_bite_01.jpg → MASK SAVED
# [OK] 06_mouse_bite_09.jpg → MASK SAVED
# [OK] 11_mouse_bite_03.jpg → MASK SAVED
# [OK] 09_mouse_bite_07.jpg → MASK SAVED
# [OK] 07_mouse_bite_06.jpg → MASK SAVED
# [OK] 10_mouse_bite_01.jpg → MASK SAVED
# [OK] 08_mouse_bite_05.jpg → MASK SAVED
# [OK] 07_mouse_bite_09.jpg → MASK SAVED
# [OK] 08_mouse_bite_08.jpg → MASK SAVED
# [OK] 06_mouse_bite_05.jpg → MASK SAVED
# [OK] 09_mouse_bite_09.jpg → MASK SAVED
# [OK] 08_mouse_bite_01.jpg → MASK SAVED
# [OK] 10_mouse_bite_05.jpg → MASK SAVED
# [OK] 09_mouse_bite_03.jpg → MASK SAVED
# [OK] 11_mouse_bite_02.jpg → MASK SAVED
# [OK] 11_mouse_bite_04.jpg → MASK SAVED
# [OK] 09_mouse_bite_08.jpg → MASK SAVED
# [OK] 07_mouse_bite_04.jpg → MASK SAVED
# [OK] 08_mouse_bite_09.jpg → MASK SAVED
# [OK] 09_mouse_bite_02.jpg → MASK SAVED
# [OK] 06_mouse_bite_06.jpg → MASK SAVED
# [OK] 06_mouse_bite_04.jpg → MASK SAVED
# [OK] 11_mouse_bite_08.jpg → MASK SAVED
# [OK] 10_mouse_bite_04.jpg → MASK SAVED
# [OK] 07_mouse_bite_08.jpg → MASK SAVED
# [OK] 06_mouse_bite_07.jpg → MASK SAVED
# [OK] 08_mouse_bite_07.jpg → MASK SAVED
# [OK] 08_mouse_bite_04.jpg → MASK SAVED
# [OK] 06_mouse_bite_08.jpg → MASK SAVED
# [OK] 07_mouse_bite_10.jpg → MASK SAVED
# [OK] 06_mouse_bite_03.jpg → MASK SAVED
# [OK] 08_mouse_bite_10.jpg → MASK SAVED
# [OK] 08_mouse_bite_03.jpg → MASK SAVED
# [OK] 09_mouse_bite_10.jpg → MASK SAVED
# [OK] 08_mouse_bite_06.jpg → MASK SAVED
# [OK] 09_mouse_bite_06.jpg → MASK SAVED
# [OK] 11_mouse_bite_07.jpg → MASK SAVED
# [OK] 09_mouse_bite_04.jpg → MASK SAVED
# [OK] 07_mouse_bite_02.jpg → MASK SAVED
# [OK] 07_mouse_bite_01.jpg → MASK SAVED
# [OK] 09_mouse_bite_05.jpg → MASK SAVED
# [OK] 07_mouse_bite_05.jpg → MASK SAVED
# [OK] 11_mouse_bite_01.jpg → MASK SAVED
# [OK] 08_mouse_bite_02.jpg → MASK SAVED
# [OK] 11_mouse_bite_06.jpg → MASK SAVED
# [OK] 10_mouse_bite_02.jpg → MASK SAVED
# [OK] 07_mouse_bite_03.jpg → MASK SAVED
# [OK] 11_mouse_bite_05.jpg → MASK SAVED
# [OK] 07_mouse_bite_07.jpg → MASK SAVED
# [OK] 06_mouse_bite_10.jpg → MASK SAVED
# [OK] 10_mouse_bite_03.jpg → MASK SAVED
# [OK] 05_mouse_bite_07.jpg → MASK SAVED
# [OK] 04_mouse_bite_18.jpg → MASK SAVED
# [OK] 01_mouse_bite_08.jpg → MASK SAVED
# [OK] 04_mouse_bite_07.jpg → MASK SAVED
# [OK] 05_mouse_bite_08.jpg → MASK SAVED
# [OK] 01_mouse_bite_09.jpg → MASK SAVED
# [OK] 01_mouse_bite_13.jpg → MASK SAVED
# [OK] 04_mouse_bite_20.jpg → MASK SAVED
# [OK] 04_mouse_bite_02.jpg → MASK SAVED
# [OK] 04_mouse_bite_14.jpg → MASK SAVED
# [OK] 05_mouse_bite_03.jpg → MASK SAVED
# [OK] 01_mouse_bite_11.jpg → MASK SAVED
# [OK] 05_mouse_bite_04.jpg → MASK SAVED
# [OK] 06_mouse_bite_01.jpg → MASK SAVED
# [OK] 01_mouse_bite_12.jpg → MASK SAVED
# [OK] 04_mouse_bite_08.jpg → MASK SAVED
# [OK] 04_mouse_bite_09.jpg → MASK SAVED
# [OK] 04_mouse_bite_06.jpg → MASK SAVED
# [OK] 01_mouse_bite_18.jpg → MASK SAVED
# [OK] 01_mouse_bite_17.jpg → MASK SAVED
# [OK] 01_mouse_bite_10.jpg → MASK SAVED
# [OK] 01_mouse_bite_06.jpg → MASK SAVED
# [OK] 05_mouse_bite_10.jpg → MASK SAVED
# [OK] 04_mouse_bite_04.jpg → MASK SAVED
# [OK] 04_mouse_bite_17.jpg → MASK SAVED
# [OK] 01_mouse_bite_14.jpg → MASK SAVED
# [OK] 04_mouse_bite_16.jpg → MASK SAVED
# [OK] 04_mouse_bite_03.jpg → MASK SAVED
# [OK] 04_mouse_bite_13.jpg → MASK SAVED
# [OK] 04_mouse_bite_05.jpg → MASK SAVED
# [OK] 01_mouse_bite_07.jpg → MASK SAVED
# [OK] 04_mouse_bite_11.jpg → MASK SAVED
# [OK] 01_mouse_bite_20.jpg → MASK SAVED
# [OK] 05_mouse_bite_06.jpg → MASK SAVED
# [OK] 01_mouse_bite_16.jpg → MASK SAVED
# [OK] 04_mouse_bite_19.jpg → MASK SAVED
# [OK] 04_mouse_bite_01.jpg → MASK SAVED
# [OK] 01_mouse_bite_15.jpg → MASK SAVED
# [OK] 04_mouse_bite_10.jpg → MASK SAVED
# [OK] 04_mouse_bite_12.jpg → MASK SAVED
# [OK] 05_mouse_bite_05.jpg → MASK SAVED
# [OK] 04_mouse_bite_15.jpg → MASK SAVED
# [OK] 05_mouse_bite_02.jpg → MASK SAVED
# [OK] 01_mouse_bite_19.jpg → MASK SAVED
# [OK] 05_mouse_bite_01.jpg → MASK SAVED
# [OK] 05_mouse_bite_09.jpg → MASK SAVED
# [OK] 01_mouse_bite_01.jpg → MASK SAVED
# [OK] 01_mouse_bite_04.jpg → MASK SAVED
# [OK] 01_mouse_bite_02.jpg → MASK SAVED
# [OK] 01_mouse_bite_05.jpg → MASK SAVED
# [OK] 01_mouse_bite_03.jpg → MASK SAVED
#
# ✔ MODULE-1 COMPLETED ✔

# %% [markdown]
# Module 2: Contour Detection and ROI Extraction

# %%
import os
import cv2
import csv
import numpy as np

BASE_PATH = "/content/drive/MyDrive/PCB_DATASET"

MASK_DIR   = f"{BASE_PATH}/outputs/mask"
ALIGN_DIR  = f"{BASE_PATH}/outputs/aligned"
ROI_ROOT   = f"{BASE_PATH}/data/rois"
CSV_PATH   = f"{ROI_ROOT}/annotations.csv"

os.makedirs(ROI_ROOT, exist_ok=True)

# %% [markdown]
# Initialize CSV

# %%
if not os.path.exists(CSV_PATH):
    with open(CSV_PATH,'w',newline='') as f:
        csv.writer(f).writerow(["filename","x","y","w","h","label"])

# %% [markdown]
# Extract ROIs for One Image

# %%
def extract_rois(mask, aligned, defect, base):
    roi_dir = os.path.join(ROI_ROOT, defect)
    os.makedirs(roi_dir, exist_ok=True)

    if defect.lower() == "spur":
        min_area = 300
        min_white = 50
    else:
        min_area = 80
        min_white = 20

    cnts,_ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    roi_count = 0
    rows = []

    for c in cnts:
        x,y,w,h = cv2.boundingRect(c)
        if w*h < min_area: continue
        if cv2.countNonZero(mask[y:y+h,x:x+w]) < min_white: continue

        roi = aligned[y:y+h, x:x+w]
        name = f"{base}_roi_{roi_count:04d}.jpg"
        cv2.imwrite(f"{roi_dir}/{name}", roi)

        rows.append([name,x,y,w,h,defect])
        roi_count += 1

    with open(CSV_PATH,'a',newline='') as f:
        csv.writer(f).writerows(rows)

    return roi_count

# %%
def module2():
    files = os.listdir(OUT_MASK)
    total = 0

    for fname in files:
        if not fname.lower().endswith((".jpg",".png",".jpeg")): continue

        defect = fname.split("_")[1]
        base = fname.split(".")[0]

        mask = cv2.imread(f"{OUT_MASK}/{fname}",0)
        aligned = cv2.imread(f"{OUT_ALIGN}/{fname}")

        if mask is None or aligned is None:
            print("[MISSING]:", fname)
            continue

        count = extract_rois(mask, aligned, defect, base)
        total += count

        print(f"[OK] {fname} → {count} ROIs")

    print("\n✔ MODULE-2 COMPLETED — Total ROIs:", total)

# %%
module2()
# Out:
# [OK] 12_spur_08.jpg → 5 ROIs
# [OK] 11_spur_10.jpg → 5 ROIs
# [OK] 12_spur_03.jpg → 5 ROIs
# [OK] 12_spur_01.jpg → 4 ROIs
# [OK] 11_spur_09.jpg → 4 ROIs
# [OK] 12_spur_02.jpg → 5 ROIs
# [OK] 11_spur_04.jpg → 5 ROIs
# [OK] 12_spur_04.jpg → 3 ROIs
# [OK] 12_spur_10.jpg → 5 ROIs
# [OK] 12_spur_07.jpg → 5 ROIs
# [OK] 12_spur_05.jpg → 4 ROIs
# [OK] 11_spur_07.jpg → 5 ROIs
# [OK] 11_spur_06.jpg → 4 ROIs
# [OK] 11_spur_05.jpg → 5 ROIs
# [OK] 12_spur_09.jpg → 4 ROIs
# [OK] 11_spur_08.jpg → 5 ROIs
# [OK] 12_spur_06.jpg → 5 ROIs
# [OK] 07_spur_03.jpg → 5 ROIs
# [OK] 05_spur_02.jpg → 5 ROIs
# [OK] 08_spur_06.jpg → 3 ROIs
# [OK] 07_spur_02.jpg → 5 ROIs
# [OK] 06_spur_07.jpg → 5 ROIs
# [OK] 10_spur_01.jpg → 5 ROIs
# [OK] 10_spur_03.jpg → 5 ROIs
# [OK] 06_spur_09.jpg → 7 ROIs
# [OK] 05_spur_09.jpg → 5 ROIs
# [OK] 08_spur_07.jpg → 5 ROIs
# [OK] 06_spur_04.jpg → 4 ROIs
# [OK] 08_spur_05.jpg → 5 ROIs
# [OK] 07_spur_09.jpg → 5 ROIs
# [OK] 07_spur_05.jpg → 5 ROIs
# [OK] 09_spur_10.jpg → 5 ROIs
# [OK] 11_spur_02.jpg → 4 ROIs
# [OK] 09_spur_06.jpg → 5 ROIs
# [OK] 06_spur_02.jpg → 5 ROIs
# [OK] 07_spur_01.jpg → 5 ROIs
# [OK] 09_spur_03.jpg → 5 ROIs
# [OK] 09_spur_09.jpg → 5 ROIs
# [OK] 05_spur_01.jpg → 5 ROIs
# [OK] 06_spur_08.jpg → 274 ROIs
# [OK] 08_spur_10.jpg → 3 ROIs
# [OK] 08_spur_08.jpg → 4 ROIs
# [OK] 11_spur_01.jpg → 5 ROIs
# [OK] 04_spur_20.jpg → 3 ROIs
# [OK] 05_spur_08.jpg → 5 ROIs
# [OK] 05_spur_04.jpg → 6 ROIs
# [OK] 05_spur_03.jpg → 6 ROIs
# [OK] 08_spur_03.jpg → 3 ROIs
# [OK] 05_spur_10.jpg → 6 ROIs
# [OK] 07_spur_10.jpg → 5 ROIs
# [OK] 06_spur_06.jpg → 6 ROIs
# [OK] 08_spur_02.jpg → 4 ROIs
# [OK] 07_spur_08.jpg → 5 ROIs
# [OK] 04_spur_19.jpg → 3 ROIs
# [OK] 09_spur_02.jpg → 5 ROIs
# [OK] 07_spur_07.jpg → 5 ROIs
# [OK] 08_spur_01.jpg → 4 ROIs
# [OK] 06_spur_03.jpg → 5 ROIs
# [OK] 09_spur_05.jpg → 5 ROIs
# [OK] 07_spur_04.jpg → 5 ROIs
# [OK] 07_spur_06.jpg → 5 ROIs
# [OK] 10_spur_05.jpg → 5 ROIs
# [OK] 05_spur_07.jpg → 7 ROIs
# [OK] 09_spur_08.jpg → 5 ROIs
# [OK] 05_spur_05.jpg → 6 ROIs
# [OK] 10_spur_02.jpg → 5 ROIs
# [OK] 09_spur_07.jpg → 5 ROIs
# [OK] 08_spur_09.jpg → 5 ROIs
# [OK] 06_spur_10.jpg → 5 ROIs
# [OK] 09_spur_04.jpg → 5 ROIs
# [OK] 05_spur_06.jpg → 5 ROIs
# [OK] 10_spur_04.jpg → 5 ROIs
# [OK] 06_spur_05.jpg → 5 ROIs
# [OK] 06_spur_01.jpg → 6 ROIs
# [OK] 09_spur_01.jpg → 5 ROIs
# [OK] 08_spur_04.jpg → 4 ROIs
# [OK] 11_spur_03.jpg → 6 ROIs
# [OK] 01_spur_10.jpg → 1 ROIs
# [OK] 01_spur_14.jpg → 0 ROIs
# [OK] 01_spur_08.jpg → 1 ROIs
# [OK] 04_spur_16.jpg → 3 ROIs
# [OK] 04_spur_07.jpg → 3 ROIs
# [OK] 04_spur_13.jpg → 3 ROIs
# [OK] 01_spur_11.jpg → 1 ROIs
# [OK] 04_spur_10.jpg → 3 ROIs
# [OK] 04_spur_15.jpg → 3 ROIs
# [OK] 01_spur_03.jpg → 0 ROIs
# [OK] 04_spur_14.jpg → 3 ROIs
# [OK] 01_spur_17.jpg → 0 ROIs
# [OK] 04_spur_02.jpg → 3 ROIs
# [OK] 04_spur_03.jpg → 3 ROIs
# [OK] 01_spur_01.jpg → 0 ROIs
# [OK] 04_spur_01.jpg → 3 ROIs
# [OK] 04_spur_04.jpg → 3 ROIs
# [OK] 04_spur_09.jpg → 3 ROIs
# [OK] 01_spur_16.jpg → 0 ROIs
# [OK] 01_spur_20.jpg → 2 ROIs
# [OK] 01_spur_09.jpg → 0 ROIs
# [OK] 04_spur_06.jpg → 3 ROIs
# [OK] 01_spur_19.jpg → 2 ROIs
# [OK] 01_spur_06.jpg → 0 ROIs
# [OK] 01_spur_12.jpg → 0 ROIs
# [OK] 01_spur_18.jpg → 0 ROIs
# [OK] 04_spur_05.jpg → 3 ROIs
# [OK] 01_spur_04.jpg → 0 ROIs
# [OK] 04_spur_18.jpg → 3 ROIs
# [OK] 01_spur_13.jpg → 0 ROIs
# [OK] 04_spur_17.jpg → 3 ROIs
# [OK] 01_spur_05.jpg → 0 ROIs
# [OK] 04_spur_08.jpg → 3 ROIs
# [OK] 04_spur_11.jpg → 3 ROIs
# [OK] 04_spur_12.jpg → 3 ROIs
# [OK] 01_spur_07.jpg → 1 ROIs
# [OK] 01_spur_15.jpg → 1 ROIs
# [OK] 01_spur_02.jpg → 1 ROIs
# [OK] 08_spurious_copper_10.jpg → 5 ROIs
# [OK] 09_spurious_copper_07.jpg → 7 ROIs
# [OK] 12_spurious_copper_06.jpg → 5 ROIs
# [OK] 09_spurious_copper_05.jpg → 5 ROIs
# [OK] 09_spurious_copper_06.jpg → 7 ROIs
# [OK] 12_spurious_copper_10.jpg → 5 ROIs
# [OK] 08_spurious_copper_08.jpg → 6 ROIs
# [OK] 12_spurious_copper_03.jpg → 5 ROIs
# [OK] 10_spurious_copper_04.jpg → 5 ROIs
# [OK] 09_spurious_copper_02.jpg → 7 ROIs
# [OK] 09_spurious_copper_09.jpg → 4 ROIs
# [OK] 12_spurious_copper_01.jpg → 6 ROIs
# [OK] 10_spurious_copper_05.jpg → 7 ROIs
# [OK] 10_spurious_copper_06.jpg → 5 ROIs
# [OK] 11_spurious_copper_08.jpg → 5 ROIs
# [OK] 12_spurious_copper_09.jpg → 7 ROIs
# [OK] 11_spurious_copper_09.jpg → 6 ROIs
# [OK] 12_spurious_copper_08.jpg → 8 ROIs
# [OK] 11_spurious_copper_07.jpg → 6 ROIs
# [OK] 11_spurious_copper_01.jpg → 5 ROIs
# [OK] 09_spurious_copper_10.jpg → 5 ROIs
# [OK] 10_spurious_copper_03.jpg → 6 ROIs
# [OK] 08_spurious_copper_09.jpg → 9 ROIs
# [OK] 11_spurious_copper_03.jpg → 5 ROIs
# [OK] 09_spurious_copper_04.jpg → 6 ROIs
# [OK] 09_spurious_copper_01.jpg → 5 ROIs
# [OK] 11_spurious_copper_05.jpg → 5 ROIs
# [OK] 10_spurious_copper_02.jpg → 5 ROIs
# [OK] 08_spurious_copper_07.jpg → 6 ROIs
# [OK] 10_spurious_copper_01.jpg → 5 ROIs
# [OK] 09_spurious_copper_08.jpg → 5 ROIs
# [OK] 11_spurious_copper_02.jpg → 5 ROIs
# [OK] 11_spurious_copper_06.jpg → 6 ROIs
# [OK] 11_spurious_copper_10.jpg → 5 ROIs
# [OK] 11_spurious_copper_04.jpg → 5 ROIs
# [OK] 12_spurious_copper_05.jpg → 7 ROIs
# [OK] 12_spurious_copper_07.jpg → 6 ROIs
# [OK] 12_spurious_copper_04.jpg → 5 ROIs
# [OK] 09_spurious_copper_03.jpg → 5 ROIs
# [OK] 12_spurious_copper_02.jpg → 7 ROIs
# [OK] 06_spurious_copper_05.jpg → 6 ROIs
# [OK] 06_spurious_copper_09.jpg → 6 ROIs
# [OK] 08_spurious_copper_04.jpg → 5 ROIs
# [OK] 07_spurious_copper_10.jpg → 6 ROIs
# [OK] 06_spurious_copper_02.jpg → 5 ROIs
# [OK] 07_spurious_copper_02.jpg → 5 ROIs
# [OK] 08_spurious_copper_05.jpg → 5 ROIs
# [OK] 08_spurious_copper_03.jpg → 6 ROIs
# [OK] 05_spurious_copper_04.jpg → 5 ROIs
# [OK] 06_spurious_copper_04.jpg → 2 ROIs
# [OK] 05_spurious_copper_06.jpg → 6 ROIs
# [OK] 08_spurious_copper_01.jpg → 6 ROIs
# [OK] 04_spurious_copper_14.jpg → 3 ROIs
# [OK] 06_spurious_copper_01.jpg → 8 ROIs
# [OK] 07_spurious_copper_05.jpg → 5 ROIs
# [OK] 05_spurious_copper_08.jpg → 6 ROIs
# [OK] 07_spurious_copper_03.jpg → 5 ROIs
# [OK] 07_spurious_copper_09.jpg → 8 ROIs
# [OK] 07_spurious_copper_07.jpg → 6 ROIs
# [OK] 06_spurious_copper_07.jpg → 7 ROIs
# [OK] 06_spurious_copper_08.jpg → 6 ROIs
# [OK] 05_spurious_copper_02.jpg → 5 ROIs
# [OK] 05_spurious_copper_01.jpg → 5 ROIs
# [OK] 05_spurious_copper_03.jpg → 6 ROIs
# [OK] 04_spurious_copper_20.jpg → 2 ROIs
# [OK] 07_spurious_copper_06.jpg → 6 ROIs
# [OK] 05_spurious_copper_07.jpg → 4 ROIs
# [OK] 06_spurious_copper_10.jpg → 5 ROIs
# [OK] 04_spurious_copper_16.jpg → 3 ROIs
# [OK] 04_spurious_copper_18.jpg → 2 ROIs
# [OK] 05_spurious_copper_09.jpg → 6 ROIs
# [OK] 04_spurious_copper_17.jpg → 3 ROIs
# [OK] 04_spurious_copper_19.jpg → 3 ROIs
# [OK] 07_spurious_copper_01.jpg → 6 ROIs
# [OK] 04_spurious_copper_15.jpg → 3 ROIs
# [OK] 07_spurious_copper_04.jpg → 5 ROIs
# [OK] 06_spurious_copper_03.jpg → 5 ROIs
# [OK] 04_spurious_copper_13.jpg → 2 ROIs
# [OK] 06_spurious_copper_06.jpg → 5 ROIs
# [OK] 08_spurious_copper_02.jpg → 6 ROIs
# [OK] 05_spurious_copper_05.jpg → 6 ROIs
# [OK] 07_spurious_copper_08.jpg → 5 ROIs
# [OK] 08_spurious_copper_06.jpg → 5 ROIs
# [OK] 05_spurious_copper_10.jpg → 5 ROIs
# [OK] 04_spurious_copper_09.jpg → 2 ROIs
# [OK] 01_spurious_copper_08.jpg → 3 ROIs
# [OK] 04_spurious_copper_07.jpg → 0 ROIs
# [OK] 01_spurious_copper_01.jpg → 4 ROIs
# [OK] 01_spurious_copper_11.jpg → 3 ROIs
# [OK] 01_spurious_copper_12.jpg → 3 ROIs
# [OK] 01_spurious_copper_19.jpg → 3 ROIs
# [OK] 04_spurious_copper_04.jpg → 1 ROIs
# [OK] 01_spurious_copper_20.jpg → 4 ROIs
# [OK] 01_spurious_copper_16.jpg → 4 ROIs
# [OK] 04_spurious_copper_02.jpg → 0 ROIs
# [OK] 01_spurious_copper_15.jpg → 4 ROIs
# [OK] 01_spurious_copper_06.jpg → 4 ROIs
# [OK] 01_spurious_copper_05.jpg → 3 ROIs
# [OK] 01_spurious_copper_07.jpg → 3 ROIs
# [OK] 01_spurious_copper_02.jpg → 3 ROIs
# [OK] 04_spurious_copper_11.jpg → 1 ROIs
# [OK] 04_spurious_copper_10.jpg → 3 ROIs
# [OK] 01_spurious_copper_10.jpg → 4 ROIs
# [OK] 04_spurious_copper_03.jpg → 1 ROIs
# [OK] 01_spurious_copper_14.jpg → 3 ROIs
# [OK] 04_spurious_copper_05.jpg → 0 ROIs
# [OK] 01_spurious_copper_18.jpg → 3 ROIs
# [OK] 04_spurious_copper_08.jpg → 1 ROIs
# [OK] 01_spurious_copper_04.jpg → 3 ROIs
# [OK] 04_spurious_copper_01.jpg → 2 ROIs
# [OK] 01_spurious_copper_03.jpg → 3 ROIs
# [OK] 01_spurious_copper_13.jpg → 5 ROIs
# [OK] 04_spurious_copper_12.jpg → 2 ROIs
# [OK] 01_spurious_copper_09.jpg → 3 ROIs
# [OK] 01_spurious_copper_17.jpg → 3 ROIs
# [OK] 04_spurious_copper_06.jpg → 0 ROIs
# [OK] 08_short_09.jpg → 6 ROIs
# [OK] 11_short_04.jpg → 5 ROIs
# [OK] 12_short_01.jpg → 5 ROIs
# [OK] 11_short_03.jpg → 5 ROIs
# [OK] 09_short_07.jpg → 6 ROIs
# [OK] 09_short_03.jpg → 5 ROIs
# [OK] 09_short_01.jpg → 6 ROIs
# [OK] 12_short_10.jpg → 5 ROIs
# [OK] 12_short_02.jpg → 7 ROIs
# [OK] 09_short_02.jpg → 6 ROIs
# [OK] 10_short_01.jpg → 5 ROIs
# [OK] 11_short_02.jpg → 5 ROIs
# [OK] 09_short_10.jpg → 5 ROIs
# [OK] 10_short_04.jpg → 7 ROIs
# [OK] 11_short_09.jpg → 5 ROIs
# [OK] 11_short_10.jpg → 7 ROIs
# [OK] 11_short_01.jpg → 5 ROIs
# [OK] 11_short_05.jpg → 5 ROIs
# [OK] 11_short_08.jpg → 5 ROIs
# [OK] 09_short_04.jpg → 5 ROIs
# [OK] 09_short_09.jpg → 6 ROIs
# [OK] 12_short_04.jpg → 5 ROIs
# [OK] 10_short_02.jpg → 5 ROIs
# [OK] 10_short_05.jpg → 7 ROIs
# [OK] 12_short_07.jpg → 5 ROIs
# [OK] 11_short_06.jpg → 5 ROIs
# [OK] 09_short_08.jpg → 5 ROIs
# [OK] 12_short_03.jpg → 5 ROIs
# [OK] 11_short_07.jpg → 5 ROIs
# [OK] 09_short_06.jpg → 5 ROIs
# [OK] 09_short_05.jpg → 5 ROIs
# [OK] 12_short_06.jpg → 5 ROIs
# [OK] 12_short_09.jpg → 6 ROIs
# [OK] 12_short_08.jpg → 6 ROIs
# [OK] 08_short_10.jpg → 6 ROIs
# [OK] 12_short_05.jpg → 5 ROIs
# [OK] 10_short_03.jpg → 6 ROIs
# [OK] 04_short_20.jpg → 3 ROIs
# [OK] 04_short_13.jpg → 3 ROIs
# [OK] 06_short_11.jpg → 5 ROIs
# [OK] 07_short_01.jpg → 5 ROIs
# [OK] 05_short_07.jpg → 5 ROIs
# [OK] 06_short_06.jpg → 7 ROIs
# [OK] 04_short_15.jpg → 3 ROIs
# [OK] 07_short_03.jpg → 6 ROIs
# [OK] 08_short_03.jpg → 5 ROIs
# [OK] 05_short_03.jpg → 3 ROIs
# [OK] 08_short_07.jpg → 7 ROIs
# [OK] 06_short_09.jpg → 5 ROIs
# [OK] 04_short_10.jpg → 4 ROIs
# [OK] 06_short_04.jpg → 6 ROIs
# [OK] 06_short_03.jpg → 5 ROIs
# [OK] 04_short_12.jpg → 3 ROIs
# [OK] 05_short_04.jpg → 3 ROIs
# [OK] 07_short_06.jpg → 5 ROIs
# [OK] 07_short_08.jpg → 6 ROIs
# [OK] 04_short_14.jpg → 4 ROIs
# [OK] 06_short_10.jpg → 5 ROIs
# [OK] 08_short_08.jpg → 5 ROIs
# [OK] 08_short_04.jpg → 5 ROIs
# [OK] 05_short_05.jpg → 3 ROIs
# [OK] 06_short_05.jpg → 5 ROIs
# [OK] 04_short_17.jpg → 3 ROIs
# [OK] 08_short_01.jpg → 5 ROIs
# [OK] 05_short_09.jpg → 3 ROIs
# [OK] 08_short_06.jpg → 5 ROIs
# [OK] 07_short_02.jpg → 5 ROIs
# [OK] 05_short_08.jpg → 3 ROIs
# [OK] 04_short_03.jpg → 3 ROIs
# [OK] 04_short_19.jpg → 3 ROIs
# [OK] 07_short_04.jpg → 6 ROIs
# [OK] 07_short_05.jpg → 5 ROIs
# [OK] 08_short_02.jpg → 5 ROIs
# [OK] 07_short_10.jpg → 5 ROIs
# [OK] 08_short_05.jpg → 6 ROIs
# [OK] 04_short_11.jpg → 3 ROIs
# [OK] 05_short_01.jpg → 3 ROIs
# [OK] 06_short_07.jpg → 5 ROIs
# [OK] 04_short_09.jpg → 5 ROIs
# [OK] 06_short_08.jpg → 5 ROIs
# [OK] 05_short_02.jpg → 3 ROIs
# [OK] 05_short_10.jpg → 3 ROIs
# [OK] 04_short_18.jpg → 3 ROIs
# [OK] 07_short_07.jpg → 6 ROIs
# [OK] 07_short_09.jpg → 6 ROIs
# [OK] 04_short_16.jpg → 3 ROIs
# [OK] 05_short_06.jpg → 3 ROIs
# [OK] 01_short_14.jpg → 7 ROIs
# [OK] 01_short_20.jpg → 6 ROIs
# [OK] 01_short_04.jpg → 3 ROIs
# [OK] 01_short_01.jpg → 3 ROIs
# [OK] 01_short_07.jpg → 4 ROIs
# [OK] 01_short_13.jpg → 6 ROIs
# [OK] 01_short_19.jpg → 8 ROIs
# [OK] 04_short_07.jpg → 3 ROIs
# [OK] 06_short_01.jpg → 5 ROIs
# [OK] 01_short_02.jpg → 3 ROIs
# [OK] 04_short_01.jpg → 3 ROIs
# [OK] 01_short_15.jpg → 7 ROIs
# [OK] 01_short_10.jpg → 5 ROIs
# [OK] 01_short_18.jpg → 6 ROIs
# [OK] 01_short_16.jpg → 6 ROIs
# [OK] 04_short_04.jpg → 3 ROIs
# [OK] 06_short_02.jpg → 5 ROIs
# [OK] 04_short_05.jpg → 3 ROIs
# [OK] 01_short_05.jpg → 4 ROIs
# [OK] 01_short_03.jpg → 3 ROIs
# [OK] 01_short_17.jpg → 7 ROIs
# [OK] 04_short_08.jpg → 4 ROIs
# [OK] 01_short_09.jpg → 7 ROIs
# [OK] 04_short_06.jpg → 3 ROIs
# [OK] 01_short_06.jpg → 3 ROIs
# [OK] 04_short_02.jpg → 3 ROIs
# [OK] 01_short_08.jpg → 3 ROIs
# [OK] 01_short_11.jpg → 6 ROIs
# [OK] 01_short_12.jpg → 7 ROIs
# [OK] 12_open_circuit_06.jpg → 5 ROIs
# [OK] 12_open_circuit_04.jpg → 5 ROIs
# [OK] 11_open_circuit_08.jpg → 5 ROIs
# [OK] 12_open_circuit_10.jpg → 6 ROIs
# [OK] 11_open_circuit_03.jpg → 5 ROIs
# [OK] 11_open_circuit_04.jpg → 7 ROIs
# [OK] 09_open_circuit_08.jpg → 5 ROIs
# [OK] 12_open_circuit_09.jpg → 5 ROIs
# [OK] 11_open_circuit_06.jpg → 7 ROIs
# [OK] 11_open_circuit_01.jpg → 6 ROIs
# [OK] 10_open_circuit_01.jpg → 6 ROIs
# [OK] 12_open_circuit_01.jpg → 6 ROIs
# [OK] 09_open_circuit_09.jpg → 6 ROIs
# [OK] 09_open_circuit_10.jpg → 5 ROIs
# [OK] 11_open_circuit_02.jpg → 7 ROIs
# [OK] 11_open_circuit_10.jpg → 5 ROIs
# [OK] 12_open_circuit_05.jpg → 5 ROIs
# [OK] 11_open_circuit_07.jpg → 7 ROIs
# [OK] 12_open_circuit_08.jpg → 5 ROIs
# [OK] 01_open_circuit_01.jpg → 3 ROIs
# [OK] 11_open_circuit_09.jpg → 6 ROIs
# [OK] 12_open_circuit_02.jpg → 5 ROIs
# [OK] 10_open_circuit_03.jpg → 6 ROIs
# [OK] 12_open_circuit_07.jpg → 5 ROIs
# [OK] 10_open_circuit_04.jpg → 5 ROIs
# [OK] 10_open_circuit_06.jpg → 6 ROIs
# [OK] 10_open_circuit_05.jpg → 5 ROIs
# [OK] 12_open_circuit_03.jpg → 5 ROIs
# [OK] 10_open_circuit_02.jpg → 7 ROIs
# [OK] 11_open_circuit_05.jpg → 6 ROIs
# [OK] 06_open_circuit_10.jpg → 6 ROIs
# [OK] 09_open_circuit_02.jpg → 6 ROIs
# [OK] 08_open_circuit_05.jpg → 5 ROIs
# [OK] 08_open_circuit_02.jpg → 6 ROIs
# [OK] 08_open_circuit_03.jpg → 6 ROIs
# [OK] 08_open_circuit_10.jpg → 5 ROIs
# [OK] 09_open_circuit_01.jpg → 5 ROIs
# [OK] 07_open_circuit_10.jpg → 5 ROIs
# [OK] 07_open_circuit_07.jpg → 5 ROIs
# [OK] 07_open_circuit_02.jpg → 5 ROIs
# [OK] 07_open_circuit_04.jpg → 5 ROIs
# [OK] 08_open_circuit_09.jpg → 5 ROIs
# [OK] 06_open_circuit_08.jpg → 5 ROIs
# [OK] 07_open_circuit_05.jpg → 5 ROIs
# [OK] 06_open_circuit_09.jpg → 5 ROIs
# [OK] 09_open_circuit_06.jpg → 5 ROIs
# [OK] 08_open_circuit_07.jpg → 5 ROIs
# [OK] 06_open_circuit_07.jpg → 6 ROIs
# [OK] 09_open_circuit_05.jpg → 5 ROIs
# [OK] 08_open_circuit_01.jpg → 5 ROIs
# [OK] 07_open_circuit_09.jpg → 5 ROIs
# [OK] 08_open_circuit_04.jpg → 5 ROIs
# [OK] 07_open_circuit_01.jpg → 5 ROIs
# [OK] 09_open_circuit_07.jpg → 6 ROIs
# [OK] 08_open_circuit_06.jpg → 5 ROIs
# [OK] 06_open_circuit_06.jpg → 6 ROIs
# [OK] 07_open_circuit_08.jpg → 5 ROIs
# [OK] 07_open_circuit_06.jpg → 5 ROIs
# [OK] 07_open_circuit_03.jpg → 5 ROIs
# [OK] 08_open_circuit_08.jpg → 5 ROIs
# [OK] 09_open_circuit_04.jpg → 5 ROIs
# [OK] 09_open_circuit_03.jpg → 5 ROIs
# [OK] 04_open_circuit_01.jpg → 4 ROIs
# [OK] 06_open_circuit_01.jpg → 7 ROIs
# [OK] 01_open_circuit_20.jpg → 3 ROIs
# [OK] 04_open_circuit_02.jpg → 3 ROIs
# [OK] 06_open_circuit_05.jpg → 5 ROIs
# [OK] 05_open_circuit_03.jpg → 3 ROIs
# [OK] 04_open_circuit_05.jpg → 3 ROIs
# [OK] 04_open_circuit_03.jpg → 3 ROIs
# [OK] 04_open_circuit_10.jpg → 4 ROIs
# [OK] 05_open_circuit_02.jpg → 3 ROIs
# [OK] 05_open_circuit_08.jpg → 3 ROIs
# [OK] 01_open_circuit_18.jpg → 3 ROIs
# [OK] 04_open_circuit_17.jpg → 3 ROIs
# [OK] 06_open_circuit_03.jpg → 5 ROIs
# [OK] 05_open_circuit_06.jpg → 4 ROIs
# [OK] 05_open_circuit_05.jpg → 3 ROIs
# [OK] 05_open_circuit_10.jpg → 3 ROIs
# [OK] 05_open_circuit_09.jpg → 4 ROIs
# [OK] 01_open_circuit_19.jpg → 3 ROIs
# [OK] 04_open_circuit_19.jpg → 4 ROIs
# [OK] 06_open_circuit_04.jpg → 5 ROIs
# [OK] 06_open_circuit_02.jpg → 6 ROIs
# [OK] 04_open_circuit_04.jpg → 3 ROIs
# [OK] 04_open_circuit_20.jpg → 3 ROIs
# [OK] 01_open_circuit_17.jpg → 3 ROIs
# [OK] 04_open_circuit_18.jpg → 4 ROIs
# [OK] 05_open_circuit_07.jpg → 3 ROIs
# [OK] 04_open_circuit_11.jpg → 3 ROIs
# [OK] 04_open_circuit_13.jpg → 3 ROIs
# [OK] 04_open_circuit_09.jpg → 4 ROIs
# [OK] 01_open_circuit_16.jpg → 4 ROIs
# [OK] 01_open_circuit_15.jpg → 3 ROIs
# [OK] 04_open_circuit_15.jpg → 3 ROIs
# [OK] 05_open_circuit_01.jpg → 3 ROIs
# [OK] 04_open_circuit_12.jpg → 3 ROIs
# [OK] 01_open_circuit_14.jpg → 3 ROIs
# [OK] 04_open_circuit_07.jpg → 3 ROIs
# [OK] 04_open_circuit_06.jpg → 3 ROIs
# [OK] 04_open_circuit_08.jpg → 3 ROIs
# [OK] 05_open_circuit_04.jpg → 6 ROIs
# [OK] 04_open_circuit_16.jpg → 3 ROIs
# [OK] 04_open_circuit_14.jpg → 3 ROIs
# [OK] 01_open_circuit_13.jpg → 3 ROIs
# [OK] 01_open_circuit_12.jpg → 3 ROIs
# [OK] 01_open_circuit_05.jpg → 3 ROIs
# [OK] 01_open_circuit_07.jpg → 3 ROIs
# [OK] 01_open_circuit_10.jpg → 3 ROIs
# [OK] 01_open_circuit_02.jpg → 4 ROIs
# [OK] 01_open_circuit_11.jpg → 3 ROIs
# [OK] 01_open_circuit_06.jpg → 3 ROIs
# [OK] 01_open_circuit_04.jpg → 3 ROIs
# [OK] 01_open_circuit_09.jpg → 3 ROIs
# [OK] 01_open_circuit_03.jpg → 3 ROIs
# [OK] 01_open_circuit_08.jpg → 3 ROIs
# [OK] 12_missing_hole_03.jpg → 6 ROIs
# [OK] 12_missing_hole_10.jpg → 7 ROIs
# [OK] 12_missing_hole_04.jpg → 7 ROIs
# [OK] 12_missing_hole_07.jpg → 5 ROIs
# [OK] 12_missing_hole_08.jpg → 5 ROIs
# [OK] 12_missing_hole_05.jpg → 6 ROIs
# [OK] 12_missing_hole_06.jpg → 6 ROIs
# [OK] 12_missing_hole_09.jpg → 6 ROIs
# [OK] 12_missing_hole_02.jpg → 5 ROIs
# [OK] 07_missing_hole_08.jpg → 5 ROIs
# [OK] 07_missing_hole_10.jpg → 5 ROIs
# [OK] 09_missing_hole_07.jpg → 7 ROIs
# [OK] 10_missing_hole_04.jpg → 5 ROIs
# [OK] 11_missing_hole_04.jpg → 5 ROIs
# [OK] 07_missing_hole_09.jpg → 5 ROIs
# [OK] 09_missing_hole_10.jpg → 5 ROIs
# [OK] 08_missing_hole_06.jpg → 5 ROIs
# [OK] 07_missing_hole_03.jpg → 5 ROIs
# [OK] 07_missing_hole_06.jpg → 5 ROIs
# [OK] 10_missing_hole_05.jpg → 5 ROIs
# [OK] 09_missing_hole_06.jpg → 6 ROIs
# [OK] 09_missing_hole_01.jpg → 5 ROIs
# [OK] 08_missing_hole_07.jpg → 6 ROIs
# [OK] 06_missing_hole_09.jpg → 6 ROIs
# [OK] 11_missing_hole_07.jpg → 5 ROIs
# [OK] 08_missing_hole_10.jpg → 5 ROIs
# [OK] 11_missing_hole_06.jpg → 5 ROIs
# [OK] 09_missing_hole_04.jpg → 6 ROIs
# [OK] 11_missing_hole_01.jpg → 5 ROIs
# [OK] 11_missing_hole_02.jpg → 5 ROIs
# [OK] 08_missing_hole_01.jpg → 5 ROIs
# [OK] 09_missing_hole_03.jpg → 5 ROIs
# [OK] 12_missing_hole_01.jpg → 5 ROIs
# [OK] 11_missing_hole_08.jpg → 5 ROIs
# [OK] 09_missing_hole_08.jpg → 5 ROIs
# [OK] 10_missing_hole_03.jpg → 5 ROIs
# [OK] 08_missing_hole_03.jpg → 6 ROIs
# [OK] 07_missing_hole_05.jpg → 5 ROIs
# [OK] 06_missing_hole_10.jpg → 5 ROIs
# [OK] 08_missing_hole_09.jpg → 5 ROIs
# [OK] 11_missing_hole_09.jpg → 5 ROIs
# [OK] 08_missing_hole_04.jpg → 4 ROIs
# [OK] 08_missing_hole_08.jpg → 5 ROIs
# [OK] 11_missing_hole_05.jpg → 5 ROIs
# [OK] 11_missing_hole_03.jpg → 5 ROIs
# [OK] 09_missing_hole_02.jpg → 5 ROIs
# [OK] 07_missing_hole_02.jpg → 5 ROIs
# [OK] 09_missing_hole_05.jpg → 6 ROIs
# [OK] 10_missing_hole_01.jpg → 5 ROIs
# [OK] 08_missing_hole_02.jpg → 5 ROIs
# [OK] 07_missing_hole_04.jpg → 5 ROIs
# [OK] 10_missing_hole_02.jpg → 5 ROIs
# [OK] 07_missing_hole_07.jpg → 5 ROIs
# [OK] 08_missing_hole_05.jpg → 5 ROIs
# [OK] 11_missing_hole_10.jpg → 5 ROIs
# [OK] 07_missing_hole_01.jpg → 5 ROIs
# [OK] 09_missing_hole_09.jpg → 5 ROIs
# [OK] 06_missing_hole_08.jpg → 5 ROIs
# [OK] 05_missing_hole_05.jpg → 5 ROIs
# [OK] 04_missing_hole_13.jpg → 3 ROIs
# [OK] 04_missing_hole_18.jpg → 3 ROIs
# [OK] 04_missing_hole_15.jpg → 3 ROIs
# [OK] 04_missing_hole_03.jpg → 3 ROIs
# [OK] 04_missing_hole_05.jpg → 3 ROIs
# [OK] 04_missing_hole_12.jpg → 3 ROIs
# [OK] 05_missing_hole_03.jpg → 5 ROIs
# [OK] 04_missing_hole_17.jpg → 3 ROIs
# [OK] 06_missing_hole_01.jpg → 5 ROIs
# [OK] 04_missing_hole_10.jpg → 3 ROIs
# [OK] 04_missing_hole_11.jpg → 3 ROIs
# [OK] 05_missing_hole_06.jpg → 5 ROIs
# [OK] 05_missing_hole_10.jpg → 5 ROIs
# [OK] 04_missing_hole_04.jpg → 3 ROIs
# [OK] 05_missing_hole_08.jpg → 5 ROIs
# [OK] 06_missing_hole_06.jpg → 7 ROIs
# [OK] 04_missing_hole_07.jpg → 3 ROIs
# [OK] 06_missing_hole_02.jpg → 5 ROIs
# [OK] 04_missing_hole_08.jpg → 3 ROIs
# [OK] 04_missing_hole_14.jpg → 3 ROIs
# [OK] 05_missing_hole_07.jpg → 5 ROIs
# [OK] 04_missing_hole_20.jpg → 3 ROIs
# [OK] 05_missing_hole_04.jpg → 5 ROIs
# [OK] 05_missing_hole_02.jpg → 4 ROIs
# [OK] 04_missing_hole_09.jpg → 3 ROIs
# [OK] 05_missing_hole_09.jpg → 5 ROIs
# [OK] 04_missing_hole_06.jpg → 3 ROIs
# [OK] 06_missing_hole_07.jpg → 5 ROIs
# [OK] 04_missing_hole_02.jpg → 3 ROIs
# [OK] 06_missing_hole_03.jpg → 5 ROIs
# [OK] 06_missing_hole_05.jpg → 5 ROIs
# [OK] 04_missing_hole_19.jpg → 3 ROIs
# [OK] 06_missing_hole_04.jpg → 5 ROIs
# [OK] 05_missing_hole_01.jpg → 3 ROIs
# [OK] 04_missing_hole_16.jpg → 3 ROIs
# [OK] 01_missing_hole_12.jpg → 3 ROIs
# [OK] 01_missing_hole_02.jpg → 3 ROIs
# [OK] 01_missing_hole_18.jpg → 3 ROIs
# [OK] 01_missing_hole_10.jpg → 3 ROIs
# [OK] 01_missing_hole_05.jpg → 6 ROIs
# [OK] 04_missing_hole_01.jpg → 3 ROIs
# [OK] 01_missing_hole_01.jpg → 3 ROIs
# [OK] 01_missing_hole_07.jpg → 3 ROIs
# [OK] 01_missing_hole_16.jpg → 3 ROIs
# [OK] 01_missing_hole_14.jpg → 3 ROIs
# [OK] 01_missing_hole_11.jpg → 3 ROIs
# [OK] 01_missing_hole_04.jpg → 3 ROIs
# [OK] 01_missing_hole_13.jpg → 3 ROIs
# [OK] 01_missing_hole_20.jpg → 3 ROIs
# [OK] 01_missing_hole_15.jpg → 3 ROIs
# [OK] 01_missing_hole_09.jpg → 4 ROIs
# [OK] 01_missing_hole_08.jpg → 3 ROIs
# [OK] 01_missing_hole_17.jpg → 3 ROIs
# [OK] 01_missing_hole_03.jpg → 3 ROIs
# [OK] 01_missing_hole_19.jpg → 3 ROIs
# [OK] 01_missing_hole_06.jpg → 3 ROIs
# [OK] 11_mouse_bite_10.jpg → 5 ROIs
# [OK] 12_mouse_bite_03.jpg → 6 ROIs
# [OK] 12_mouse_bite_08.jpg → 5 ROIs
# [OK] 12_mouse_bite_06.jpg → 6 ROIs
# [OK] 12_mouse_bite_09.jpg → 5 ROIs
# [OK] 12_mouse_bite_04.jpg → 5 ROIs
# [OK] 12_mouse_bite_10.jpg → 5 ROIs
# [OK] 11_mouse_bite_09.jpg → 5 ROIs
# [OK] 12_mouse_bite_01.jpg → 5 ROIs
# [OK] 12_mouse_bite_07.jpg → 6 ROIs
# [OK] 12_mouse_bite_02.jpg → 6 ROIs
# [OK] 12_mouse_bite_05.jpg → 5 ROIs
# [OK] 06_mouse_bite_02.jpg → 6 ROIs
# [OK] 09_mouse_bite_01.jpg → 5 ROIs
# [OK] 06_mouse_bite_09.jpg → 5 ROIs
# [OK] 11_mouse_bite_03.jpg → 5 ROIs
# [OK] 09_mouse_bite_07.jpg → 6 ROIs
# [OK] 07_mouse_bite_06.jpg → 5 ROIs
# [OK] 10_mouse_bite_01.jpg → 5 ROIs
# [OK] 08_mouse_bite_05.jpg → 6 ROIs
# [OK] 07_mouse_bite_09.jpg → 5 ROIs
# [OK] 08_mouse_bite_08.jpg → 6 ROIs
# [OK] 06_mouse_bite_05.jpg → 5 ROIs
# [OK] 09_mouse_bite_09.jpg → 7 ROIs
# [OK] 08_mouse_bite_01.jpg → 6 ROIs
# [OK] 10_mouse_bite_05.jpg → 4 ROIs
# [OK] 09_mouse_bite_03.jpg → 5 ROIs
# [OK] 11_mouse_bite_02.jpg → 6 ROIs
# [OK] 11_mouse_bite_04.jpg → 5 ROIs
# [OK] 09_mouse_bite_08.jpg → 5 ROIs
# [OK] 07_mouse_bite_04.jpg → 5 ROIs
# [OK] 08_mouse_bite_09.jpg → 6 ROIs
# [OK] 09_mouse_bite_02.jpg → 6 ROIs
# [OK] 06_mouse_bite_06.jpg → 5 ROIs
# [OK] 06_mouse_bite_04.jpg → 6 ROIs
# [OK] 11_mouse_bite_08.jpg → 5 ROIs
# [OK] 10_mouse_bite_04.jpg → 6 ROIs
# [OK] 07_mouse_bite_08.jpg → 5 ROIs
# [OK] 06_mouse_bite_07.jpg → 5 ROIs
# [OK] 08_mouse_bite_07.jpg → 6 ROIs
# [OK] 08_mouse_bite_04.jpg → 6 ROIs
# [OK] 06_mouse_bite_08.jpg → 6 ROIs
# [OK] 07_mouse_bite_10.jpg → 6 ROIs
# [OK] 06_mouse_bite_03.jpg → 6 ROIs
# [OK] 08_mouse_bite_10.jpg → 6 ROIs
# [OK] 08_mouse_bite_03.jpg → 5 ROIs
# [OK] 09_mouse_bite_10.jpg → 6 ROIs
# [OK] 08_mouse_bite_06.jpg → 5 ROIs
# [OK] 09_mouse_bite_06.jpg → 6 ROIs
# [OK] 11_mouse_bite_07.jpg → 5 ROIs
# [OK] 09_mouse_bite_04.jpg → 5 ROIs
# [OK] 07_mouse_bite_02.jpg → 5 ROIs
# [OK] 07_mouse_bite_01.jpg → 5 ROIs
# [OK] 09_mouse_bite_05.jpg → 5 ROIs
# [OK] 07_mouse_bite_05.jpg → 5 ROIs
# [OK] 11_mouse_bite_01.jpg → 5 ROIs
# [OK] 08_mouse_bite_02.jpg → 4 ROIs
# [OK] 11_mouse_bite_06.jpg → 5 ROIs
# [OK] 10_mouse_bite_02.jpg → 6 ROIs
# [OK] 07_mouse_bite_03.jpg → 7 ROIs
# [OK] 11_mouse_bite_05.jpg → 5 ROIs
# [OK] 07_mouse_bite_07.jpg → 6 ROIs
# [OK] 06_mouse_bite_10.jpg → 5 ROIs
# [OK] 10_mouse_bite_03.jpg → 5 ROIs
# [OK] 05_mouse_bite_07.jpg → 7 ROIs
# [OK] 04_mouse_bite_18.jpg → 3 ROIs
# [OK] 01_mouse_bite_08.jpg → 0 ROIs
# [OK] 04_mouse_bite_07.jpg → 4 ROIs
# [OK] 05_mouse_bite_08.jpg → 6 ROIs
# [OK] 01_mouse_bite_09.jpg → 0 ROIs
# [OK] 01_mouse_bite_13.jpg → 1 ROIs
# [OK] 04_mouse_bite_20.jpg → 3 ROIs
# [OK] 04_mouse_bite_02.jpg → 3 ROIs
# [OK] 04_mouse_bite_14.jpg → 3 ROIs
# [OK] 05_mouse_bite_03.jpg → 5 ROIs
# [OK] 01_mouse_bite_11.jpg → 0 ROIs
# [OK] 05_mouse_bite_04.jpg → 5 ROIs
# [OK] 06_mouse_bite_01.jpg → 6 ROIs
# [OK] 01_mouse_bite_12.jpg → 0 ROIs
# [OK] 04_mouse_bite_08.jpg → 3 ROIs
# [OK] 04_mouse_bite_09.jpg → 3 ROIs
# [OK] 04_mouse_bite_06.jpg → 3 ROIs
# [OK] 01_mouse_bite_18.jpg → 0 ROIs
# [OK] 01_mouse_bite_17.jpg → 1 ROIs
# [OK] 01_mouse_bite_10.jpg → 1 ROIs
# [OK] 01_mouse_bite_06.jpg → 1 ROIs
# [OK] 05_mouse_bite_10.jpg → 6 ROIs
# [OK] 04_mouse_bite_04.jpg → 3 ROIs
# [OK] 04_mouse_bite_17.jpg → 3 ROIs
# [OK] 01_mouse_bite_14.jpg → 1 ROIs
# [OK] 04_mouse_bite_16.jpg → 3 ROIs
# [OK] 04_mouse_bite_03.jpg → 3 ROIs
# [OK] 04_mouse_bite_13.jpg → 3 ROIs
# [OK] 04_mouse_bite_05.jpg → 3 ROIs
# [OK] 01_mouse_bite_07.jpg → 1 ROIs
# [OK] 04_mouse_bite_11.jpg → 3 ROIs
# [OK] 01_mouse_bite_20.jpg → 1 ROIs
# [OK] 05_mouse_bite_06.jpg → 6 ROIs
# [OK] 01_mouse_bite_16.jpg → 0 ROIs
# [OK] 04_mouse_bite_19.jpg → 3 ROIs
# [OK] 04_mouse_bite_01.jpg → 3 ROIs
# [OK] 01_mouse_bite_15.jpg → 2 ROIs
# [OK] 04_mouse_bite_10.jpg → 3 ROIs
# [OK] 04_mouse_bite_12.jpg → 3 ROIs
# [OK] 05_mouse_bite_05.jpg → 5 ROIs
# [OK] 04_mouse_bite_15.jpg → 3 ROIs
# [OK] 05_mouse_bite_02.jpg → 5 ROIs
# [OK] 01_mouse_bite_19.jpg → 0 ROIs
# [OK] 05_mouse_bite_01.jpg → 5 ROIs
# [OK] 05_mouse_bite_09.jpg → 6 ROIs
# [OK] 01_mouse_bite_01.jpg → 0 ROIs
# [OK] 01_mouse_bite_04.jpg → 0 ROIs
# [OK] 01_mouse_bite_02.jpg → 0 ROIs
# [OK] 01_mouse_bite_05.jpg → 0 ROIs
# [OK] 01_mouse_bite_03.jpg → 2 ROIs
#
# ✔ MODULE-2 COMPLETED — Total ROIs: 3309
